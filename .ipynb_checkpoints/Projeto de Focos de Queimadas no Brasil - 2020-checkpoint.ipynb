# %%
import pandas as pd
import numpy as np
import plotly.express as px
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('Focos_2020-01-01_2020-12-31.csv', usecols=['datahora','estado','municipio','bioma','diasemchuva','precipitacao','riscofogo','latitude','longitude','frp'])
df
# Out:
#                    datahora             estado             municipio  \
# 0       2020/10/10 16:30:00              BAHIA              JACARACI
# 1       2020/10/10 16:30:00       MINAS GERAIS  SAO JOAO DAS MISSOES
# 2       2020/03/09 18:00:00  RIO GRANDE DO SUL                QUARAI
# 3       2020/03/09 18:00:00  RIO GRANDE DO SUL                QUARAI
# 4       2020/03/09 18:05:00           AMAZONAS              BARCELOS
# ...                     ...                ...                   ...
# 222792  2020/02/26 17:40:00        MATO GROSSO          NOVA MARINGA
# 222793  2020/02/21 17:25:00            RORAIMA             NORMANDIA
# 222794  2020/02/21 17:25:00            RORAIMA               CAROEBE
# 222795  2020/02/21 17:25:00            RORAIMA              SAO LUIZ
# 222796  2020/02/21 17:25:00            RORAIMA          RORAINOPOLIS
#
#            bioma  diasemchuva  precipitacao  riscofogo  latitude  longitude  \
# 0       Caatinga         18.0           0.0        1.0   -14.668    -42.290
# 1        Cerrado          4.0           0.2        1.0   -14.899    -44.305
# 2          Pampa         20.0           0.0        1.0   -30.395    -56.185
# 3          Pampa         20.0           0.0        1.0   -30.406    -56.182
# 4       Amazonia          0.0           0.0        0.0    -0.611    -64.795
# ...          ...          ...           ...        ...       ...        ...
# 222792  Amazonia          0.0          10.8        0.0   -12.037    -57.296
# 222793  Amazonia          9.0           0.0        1.0     4.190    -59.957
# 222794  Amazonia          8.0           0.5        0.6     1.110    -59.544
# 222795  Amazonia          4.0           1.5        0.2     0.720    -60.190
# 222796  Amazonia          6.0           0.9        0.5     0.707    -60.556
#
#          frp
# 0       12.3
# 1       16.5
# 2       15.9
# 3       11.3
# 4       13.1
# ...      ...
# 222792  15.1
# 222793  22.5
# 222794   5.8
# 222795  22.2
# 222796  40.6
#
# [222797 rows x 10 columns]

# %%
df.shape
# Out:
# (222797, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222797 entries, 0 to 222796
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   datahora      222797 non-null  object
#  1   estado        222797 non-null  object
#  2   municipio     222797 non-null  object
#  3   bioma         222797 non-null  object
#  4   diasemchuva   217727 non-null  float64
#  5   precipitacao  217727 non-null  float64
#  6   riscofogo     217727 non-null  float64
#  7   latitude      222797 non-null  float64
#  8   longitude     222797 non-null  float64
#  9   frp           220164 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 17.0+ MB

# %%
df[df['riscofogo'].isna()]
# Out:
#                    datahora               estado       municipio  \
# 58709   2020/08/26 18:38:53                 ACRE        TARAUACA
# 58710   2020/08/26 18:38:53                 ACRE           FEIJO
# 58711   2020/08/26 18:38:53                 ACRE           FEIJO
# 58712   2020/08/26 18:38:53                 ACRE           FEIJO
# 58713   2020/08/26 18:38:53                 ACRE           FEIJO
# ...                     ...                  ...             ...
# 218387  2020/12/14 15:35:00           PERNAMBUCO       PESQUEIRA
# 218388  2020/12/14 15:35:00  RIO GRANDE DO NORTE        UMARIZAL
# 218389  2020/12/14 15:35:00                CEARA    QUIXERAMOBIM
# 218390  2020/12/14 15:35:00  RIO GRANDE DO NORTE        UMARIZAL
# 218391  2020/12/14 15:35:00  RIO GRANDE DO NORTE  ESPIRITO SANTO
#
#                  bioma  diasemchuva  precipitacao  riscofogo  latitude  \
# 58709         Amazonia          NaN           NaN        NaN    -8.106
# 58710         Amazonia          NaN           NaN        NaN    -7.977
# 58711         Amazonia          NaN           NaN        NaN    -7.980
# 58712         Amazonia          NaN           NaN        NaN    -7.984
# 58713         Amazonia          NaN           NaN        NaN    -7.987
# ...                ...          ...           ...        ...       ...
# 218387        Caatinga          NaN           NaN        NaN    -8.371
# 218388        Caatinga          NaN           NaN        NaN    -6.053
# 218389        Caatinga          NaN           NaN        NaN    -5.193
# 218390        Caatinga          NaN           NaN        NaN    -6.050
# 218391  Mata Atlantica          NaN           NaN        NaN    -6.264
#
#         longitude   frp
# 58709     -70.676  21.4
# 58710     -69.956  77.6
# 58711     -69.975  14.6
# 58712     -69.943  37.6
# 58713     -69.961  43.1
# ...           ...   ...
# 218387    -36.867  21.9
# 218388    -37.831  38.6
# 218389    -39.452  30.7
# 218390    -37.805  24.5
# 218391    -35.296  65.7
#
# [5070 rows x 10 columns]

# %%
df.dropna(subset=['riscofogo'], inplace=True)

# %%
df[df['frp'].isna()]
# Out:
#                   datahora       estado      municipio     bioma  diasemchuva  \
# 42679  2020/08/17 17:01:39  MATO GROSSO         POCONE  Pantanal          0.0
# 42680  2020/08/17 17:01:39  MATO GROSSO         POCONE  Pantanal          0.0
# 42681  2020/08/17 17:01:39  MATO GROSSO        POXOREU   Cerrado         83.0
# 42682  2020/08/17 17:01:39  MATO GROSSO        POXOREU   Cerrado         84.0
# 42683  2020/08/17 17:01:39  MATO GROSSO  ALTA FLORESTA  Amazonia         84.0
# ...                    ...          ...            ...       ...          ...
# 49903  2020/08/16 16:22:33         PARA          ACARA  Amazonia         11.0
# 49904  2020/08/16 16:22:33         PARA           MOJU  Amazonia         24.0
# 49905  2020/08/16 16:22:33         PARA           MOJU  Amazonia         24.0
# 49906  2020/08/16 16:22:33         PARA           MOJU  Amazonia         24.0
# 49907  2020/08/16 16:22:33         PARA          ACARA  Amazonia         12.0
#
#        precipitacao  riscofogo   latitude  longitude  frp
# 42679           0.0        1.0 -17.380435 -57.312446  NaN
# 42680           0.0        0.8 -17.393435 -57.310446  NaN
# 42681           0.1        1.0 -15.347436 -53.825423  NaN
# 42682           0.2        1.0 -15.357436 -53.823423  NaN
# 42683           0.0        1.0  -9.550412 -56.238427  NaN
# ...             ...        ...        ...        ...  ...
# 49903           0.0        0.8  -2.335384 -48.628379  NaN
# 49904           0.0        0.9  -2.356384 -48.867380  NaN
# 49905           0.0        1.0  -2.350384 -48.856380  NaN
# 49906           0.0        0.9  -2.353384 -48.873380  NaN
# 49907           0.0        0.7  -2.163383 -48.218376  NaN
#
# [2633 rows x 10 columns]

# %%
indexNames = df[(df['riscofogo'] == -999)].index
df.drop(indexNames, inplace=True)

# %%
df[(df['diasemchuva'] == -999)]
# Out:
#                    datahora      estado              municipio  \
# 634     2020/06/18 16:45:00        PARA                 BREVES
# 657     2020/06/18 16:45:00        PARA             CURRALINHO
# 814     2020/06/20 16:35:00        PARA                 BREVES
# 1388    2020/06/22 16:20:00    MARANHAO               ARAIOSES
# 1389    2020/06/22 16:20:00    MARANHAO  AGUA DOCE DO MARANHAO
# ...                     ...         ...                    ...
# 222531  2020/01/20 15:45:00  PERNAMBUCO                 GOIANA
# 222534  2020/01/20 15:45:00  PERNAMBUCO                 GOIANA
# 222691  2020/02/13 16:30:00       BAHIA               BELMONTE
# 222712  2020/02/12 15:50:00     ALAGOAS        PORTO DE PEDRAS
# 222775  2020/02/22 16:25:00       BAHIA              CARAVELAS
#
#                  bioma  diasemchuva  precipitacao  riscofogo  latitude  \
# 634           Amazonia       -999.0           0.1        0.0    -1.552
# 657           Amazonia       -999.0           0.1        0.0    -1.619
# 814           Amazonia       -999.0           0.0        0.0    -1.660
# 1388           Cerrado       -999.0           0.0        0.1    -2.987
# 1389           Cerrado       -999.0           0.0        0.3    -2.922
# ...                ...          ...           ...        ...       ...
# 222531  Mata Atlantica       -999.0           0.2        0.9    -7.595
# 222534  Mata Atlantica       -999.0           0.2        0.9    -7.593
# 222691  Mata Atlantica       -999.0           0.0        0.6   -15.999
# 222712  Mata Atlantica       -999.0           0.9        1.0    -9.153
# 222775  Mata Atlantica       -999.0           3.5        0.5   -17.841
#
#         longitude   frp
# 634       -50.455   7.2
# 657       -50.209   5.8
# 814       -50.418  24.9
# 1388      -42.062  13.9
# 1389      -42.124  14.8
# ...           ...   ...
# 222531    -34.963  20.3
# 222534    -34.951  12.1
# 222691    -38.970  21.2
# 222712    -35.399  10.0
# 222775    -39.415   9.4
#
# [1163 rows x 10 columns]

# %%
df.describe()
# Out:
#          diasemchuva   precipitacao      riscofogo       latitude  \
# count  216473.000000  216473.000000  216473.000000  216473.000000
# mean       20.807343       0.704836       0.724293     -11.225007
# std        82.075867       3.027683       0.356427       6.420978
# min      -999.000000       0.000000       0.000000     -33.388000
# 25%         3.000000       0.000000       0.400000     -15.932000
# 50%        10.000000       0.000000       1.000000      -9.862000
# 75%        37.000000       0.000000       1.000000      -6.750000
# max       120.000000     125.500000       1.000000       5.149000
#
#            longitude            frp
# count  216473.000000  213847.000000
# mean      -53.109752      66.769436
# std         7.426435     148.156116
# min       -73.669000       0.000000
# 25%       -57.414000      15.800000
# 50%       -53.020000      29.900000
# 75%       -47.477000      63.700000
# max       -34.823000    8589.800000

# %%
medianaDiaSemChuva = df[df['diasemchuva'] != -999]['diasemchuva'].median()

# %%
df['diasemchuva'] = df['diasemchuva'].replace(-999,medianaDiaSemChuva)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216473 entries, 0 to 222796
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   datahora      216473 non-null  object
#  1   estado        216473 non-null  object
#  2   municipio     216473 non-null  object
#  3   bioma         216473 non-null  object
#  4   diasemchuva   216473 non-null  float64
#  5   precipitacao  216473 non-null  float64
#  6   riscofogo     216473 non-null  float64
#  7   latitude      216473 non-null  float64
#  8   longitude     216473 non-null  float64
#  9   frp           213847 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 18.2+ MB

# %%
df['datahora'] = pd.to_datetime(df['datahora'], format="%Y/%m/%d %H:%M:%S")

# %%
medianFRP = df[~df['frp'].isna()]['frp'].median()

# %%
df['frp'] = df['frp'].replace(np.nan,medianFRP)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 216473 entries, 0 to 222796
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   datahora      216473 non-null  datetime64[ns]
#  1   estado        216473 non-null  object
#  2   municipio     216473 non-null  object
#  3   bioma         216473 non-null  object
#  4   diasemchuva   216473 non-null  float64
#  5   precipitacao  216473 non-null  float64
#  6   riscofogo     216473 non-null  float64
#  7   latitude      216473 non-null  float64
#  8   longitude     216473 non-null  float64
#  9   frp           216473 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 18.2+ MB

# %%
df_agrupado = df.groupby(['datahora','estado','municipio']).agg({    
    'bioma':'first',
    'diasemchuva':np.median,
    'precipitacao':np.median,
    'riscofogo':np.median,
    'latitude':'first',
    'longitude':'first',
    'frp':np.median
}).reset_index()
df_agrupado.head(50)
# Out:
#               datahora               estado                   municipio  \
# 0  2020-01-01 16:45:00   MATO GROSSO DO SUL                     AMAMBAI
# 1  2020-01-01 16:45:00   MATO GROSSO DO SUL        APARECIDA DO TABOADO
# 2  2020-01-01 16:45:00   MATO GROSSO DO SUL    RIO VERDE DE MATO GROSSO
# 3  2020-01-01 16:45:00   MATO GROSSO DO SUL                 TRES LAGOAS
# 4  2020-01-01 16:45:00         MINAS GERAIS                  COROMANDEL
# 5  2020-01-01 16:45:00               PARANA                 CAMPO LARGO
# 6  2020-01-01 16:45:00       RIO DE JANEIRO                      MARICA
# 7  2020-01-01 16:45:00            SAO PAULO                      GUAIRA
# 8  2020-01-01 16:45:00            SAO PAULO                 JABOTICABAL
# 9  2020-01-01 16:45:00            SAO PAULO                  MOGI GUACU
# 10 2020-01-01 16:45:00            SAO PAULO              NOVO HORIZONTE
# 11 2020-01-01 16:45:00            SAO PAULO     SANTA CRUZ DO RIO PARDO
# 12 2020-01-01 16:45:00            SAO PAULO  SANTO ANTONIO DO ARACANGUA
# 13 2020-01-01 16:45:00            SAO PAULO                   SAO ROQUE
# 14 2020-01-01 16:50:00                GOIAS                     ACREUNA
# 15 2020-01-01 16:50:00                GOIAS          BOM JESUS DE GOIAS
# 16 2020-01-01 16:50:00                GOIAS                       EDEIA
# 17 2020-01-01 16:50:00                GOIAS                      PANAMA
# 18 2020-01-01 16:50:00                GOIAS                 TURVELANDIA
# 19 2020-01-01 16:50:00             MARANHAO             POCAO DE PEDRAS
# 20 2020-01-01 16:50:00          MATO GROSSO                 CAMPO VERDE
# 21 2020-01-01 16:50:00          MATO GROSSO                NOVA UBIRATA
# 22 2020-01-01 16:50:00          MATO GROSSO          NOVO SANTO ANTONIO
# 23 2020-01-01 16:50:00          MATO GROSSO                 PARANATINGA
# 24 2020-01-01 16:50:00          MATO GROSSO       SAO FELIX DO ARAGUAIA
# 25 2020-01-01 16:50:00          MATO GROSSO       SAO JOSE DO RIO CLARO
# 26 2020-01-01 16:50:00            TOCANTINS                     CASEARA
# 27 2020-01-01 16:55:00              RORAIMA                    UIRAMUTA
# 28 2020-01-02 15:55:00                CEARA                       CHORO
# 29 2020-01-02 15:55:00              PARAIBA                    ALHANDRA
# 30 2020-01-02 15:55:00              PARAIBA                     CAAPORA
# 31 2020-01-02 15:55:00              PARAIBA              CURRAL DE CIMA
# 32 2020-01-02 15:55:00              PARAIBA                     MOGEIRO
# 33 2020-01-02 15:55:00              PARAIBA                  SANTA RITA
# 34 2020-01-02 15:55:00  RIO GRANDE DO NORTE                 CEARA-MIRIM
# 35 2020-01-02 15:55:00  RIO GRANDE DO NORTE                     MACAIBA
# 36 2020-01-02 17:25:00    RIO GRANDE DO SUL        SANTANA DA BOA VISTA
# 37 2020-01-02 17:30:00          MATO GROSSO             BARRA DO BUGRES
# 38 2020-01-02 17:30:00          MATO GROSSO             GAUCHA DO NORTE
# 39 2020-01-02 17:30:00          MATO GROSSO             LAMBARI D'OESTE
# 40 2020-01-02 17:30:00          MATO GROSSO            MIRASSOL D'OESTE
# 41 2020-01-02 17:30:00          MATO GROSSO                      NOBRES
# 42 2020-01-02 17:30:00          MATO GROSSO                  NOVA MUTUM
# 43 2020-01-02 17:30:00          MATO GROSSO               ROSARIO OESTE
# 44 2020-01-02 17:30:00          MATO GROSSO     SANTA RITA DO TRIVELATO
# 45 2020-01-02 17:30:00          MATO GROSSO       SAO JOSE DO RIO CLARO
# 46 2020-01-02 17:30:00          MATO GROSSO  SAO JOSE DOS QUATRO MARCOS
# 47 2020-01-02 17:30:00   MATO GROSSO DO SUL                ANTONIO JOAO
# 48 2020-01-02 17:30:00   MATO GROSSO DO SUL                     CORUMBA
# 49 2020-01-02 17:30:00   MATO GROSSO DO SUL              PORTO MURTINHO
#
#              bioma  diasemchuva  precipitacao  riscofogo  latitude  longitude  \
# 0   Mata Atlantica          0.0          2.35        0.1   -23.176    -54.727
# 1          Cerrado          5.0          0.20        0.2   -20.180    -51.543
# 2          Cerrado          3.0          0.30        0.8   -18.932    -54.506
# 3          Cerrado          3.0          0.10        0.6   -20.476    -52.129
# 4          Cerrado          0.0          0.10        0.8   -18.137    -47.179
# 5   Mata Atlantica         11.0          6.10        0.1   -25.383    -49.647
# 6   Mata Atlantica          8.0          0.00        0.9   -22.957    -42.915
# 7          Cerrado          3.0          3.80        0.3   -20.326    -48.235
# 8          Cerrado          3.0          7.00        0.2   -21.312    -48.225
# 9          Cerrado          4.0          5.70        0.4   -22.236    -47.194
# 10  Mata Atlantica          2.0          3.10        0.2   -21.476    -49.231
# 11         Cerrado          8.0          2.20        0.9   -22.735    -49.486
# 12  Mata Atlantica          2.0          6.50        0.2   -20.899    -50.336
# 13  Mata Atlantica          7.0          5.60        0.1   -23.487    -47.109
# 14         Cerrado          3.0          3.80        0.1   -17.269    -50.294
# 15         Cerrado          0.0          0.20        0.1   -18.066    -49.818
# 16         Cerrado          2.0          1.80        0.0   -17.456    -49.972
# 17         Cerrado          0.0          0.00        0.1   -18.136    -49.479
# 18         Cerrado          4.0          6.70        0.0   -17.764    -50.423
# 19         Cerrado          3.0          2.55        0.0    -4.876    -45.139
# 20         Cerrado          0.0          1.70        0.1   -15.151    -54.503
# 21        Amazonia          0.0         20.00        0.0   -13.282    -54.931
# 22         Cerrado          2.0          6.05        0.1   -12.130    -51.151
# 23        Amazonia          0.0          2.40        0.2   -13.100    -54.205
# 24        Amazonia          2.0          1.80        0.5   -11.621    -51.718
# 25         Cerrado          2.0          2.80        0.0   -13.683    -56.658
# 26         Cerrado          0.0          0.60        0.2    -9.301    -49.752
# 27        Amazonia          2.5          0.00        0.9     4.316    -59.720
# 28        Caatinga          6.0          1.70        0.2    -4.781    -39.288
# 29  Mata Atlantica         10.0          2.20        0.2    -7.456    -34.867
# 30  Mata Atlantica         10.0          2.20        0.2    -7.455    -34.858
# 31        Caatinga          0.0          0.30        0.8    -6.758    -35.319
# 32        Caatinga         40.0          4.10        0.7    -7.253    -35.509
# 33  Mata Atlantica         10.0          1.60        1.0    -7.075    -34.961
# 34        Caatinga          5.0          2.65        0.0    -5.676    -35.474
# 35        Caatinga          1.0          0.80        0.0    -5.900    -35.498
# 36           Pampa          2.0          0.00        0.2   -30.827    -53.253
# 37        Amazonia          0.0          0.30        0.2   -15.286    -57.550
# 38        Amazonia          0.0          0.00        0.3   -13.185    -53.974
# 39        Amazonia          0.0          0.60        0.4   -15.381    -57.767
# 40        Amazonia          0.0          0.20        0.4   -15.658    -57.974
# 41         Cerrado          0.0          1.20        0.3   -14.598    -56.183
# 42         Cerrado          0.5          5.45        0.1   -13.420    -56.302
# 43         Cerrado          0.0          0.10        0.1   -14.722    -56.136
# 44         Cerrado          0.0          0.00        0.1   -13.656    -55.295
# 45         Cerrado          1.0         22.40        0.0   -13.815    -56.540
# 46        Amazonia          3.0          3.20        0.2   -15.623    -58.383
# 47         Cerrado          2.0          0.00        0.6   -22.272    -56.204
# 48        Pantanal          2.0          0.00        0.4   -19.670    -57.232
# 49         Cerrado          2.0          0.00        0.4   -22.068    -57.600
#
#       frp
# 0   45.25
# 1   12.60
# 2   30.20
# 3   27.10
# 4    8.00
# 5   26.20
# 6   10.10
# 7   17.80
# 8   18.90
# 9    8.70
# 10  18.20
# 11  25.20
# 12  22.80
# 13   7.00
# 14   9.10
# 15  14.60
# 16  14.65
# 17  13.90
# 18  12.20
# 19  47.35
# 20  24.10
# 21  33.10
# 22  14.55
# 23  25.20
# 24  11.90
# 25  30.30
# 26   6.50
# 27  33.30
# 28  46.70
# 29  22.20
# 30  18.00
# 31  14.20
# 32  18.90
# 33  54.90
# 34  12.30
# 35   9.40
# 36  14.20
# 37  10.60
# 38  14.90
# 39   9.50
# 40  12.70
# 41  10.90
# 42   7.90
# 43   8.10
# 44   6.90
# 45   6.90
# 46  13.80
# 47   9.80
# 48  14.95
# 49  12.70

# %%
df_agrupado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53247 entries, 0 to 53246
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datahora      53247 non-null  datetime64[ns]
#  1   estado        53247 non-null  object
#  2   municipio     53247 non-null  object
#  3   bioma         53247 non-null  object
#  4   diasemchuva   53247 non-null  float64
#  5   precipitacao  53247 non-null  float64
#  6   riscofogo     53247 non-null  float64
#  7   latitude      53247 non-null  float64
#  8   longitude     53247 non-null  float64
#  9   frp           53247 non-null  float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 4.1+ MB

# %%
df_agrupado.describe()
# Out:
#         diasemchuva  precipitacao     riscofogo      latitude     longitude  \
# count  53247.000000  53247.000000  53247.000000  53247.000000  53247.000000
# mean      22.126617      0.805653      0.674462    -12.225387    -50.045962
# std       30.810885      3.131065      0.378404      7.668856      7.082311
# min        0.000000      0.000000      0.000000    -33.388000    -73.560000
# 25%        3.000000      0.000000      0.300000    -17.468000    -54.435000
# 50%        8.000000      0.000000      0.900000    -10.934000    -49.249000
# 75%       26.500000      0.100000      1.000000     -6.406000    -44.890000
# max      120.000000     95.350000      1.000000      5.122000    -34.823000
#
#                 frp
# count  53247.000000
# mean      36.630517
# std       47.965085
# min        0.000000
# 25%       13.400000
# 50%       22.800000
# 75%       41.700000
# max     1755.500000

# %%
# Normalização por Min-Max no intervalo [1,10]
df_agrupado['frp_norm'] = round((((df_agrupado['frp'] - df_agrupado['frp'].min())/(df_agrupado['frp'].max()-df_agrupado['frp'].min())) * 9) + 1, 2)

# %%
df_agrupado
# Out:
#                  datahora              estado                 municipio  \
# 0     2020-01-01 16:45:00  MATO GROSSO DO SUL                   AMAMBAI
# 1     2020-01-01 16:45:00  MATO GROSSO DO SUL      APARECIDA DO TABOADO
# 2     2020-01-01 16:45:00  MATO GROSSO DO SUL  RIO VERDE DE MATO GROSSO
# 3     2020-01-01 16:45:00  MATO GROSSO DO SUL               TRES LAGOAS
# 4     2020-01-01 16:45:00        MINAS GERAIS                COROMANDEL
# ...                   ...                 ...                       ...
# 53242 2020-12-31 18:00:00            AMAZONAS                  CANUTAMA
# 53243 2020-12-31 18:00:00            AMAZONAS                    LABREA
# 53244 2020-12-31 18:00:00            AMAZONAS  SAO GABRIEL DA CACHOEIRA
# 53245 2020-12-31 18:00:00            RONDONIA               NOVA MAMORE
# 53246 2020-12-31 18:00:00             RORAIMA               ALTO ALEGRE
#
#                 bioma  diasemchuva  precipitacao  riscofogo  latitude  \
# 0      Mata Atlantica          0.0          2.35       0.10   -23.176
# 1             Cerrado          5.0          0.20       0.20   -20.180
# 2             Cerrado          3.0          0.30       0.80   -18.932
# 3             Cerrado          3.0          0.10       0.60   -20.476
# 4             Cerrado          0.0          0.10       0.80   -18.137
# ...               ...          ...           ...        ...       ...
# 53242        Amazonia          0.0          0.50       0.00    -7.998
# 53243        Amazonia          1.5          1.85       0.00    -8.767
# 53244        Amazonia          0.0          2.20       0.00     0.285
# 53245        Amazonia          0.0          1.15       0.25   -10.475
# 53246        Amazonia          0.0          0.40       0.10     2.937
#
#        longitude    frp  frp_norm
# 0        -54.727  45.25      1.23
# 1        -51.543  12.60      1.06
# 2        -54.506  30.20      1.15
# 3        -52.129  27.10      1.14
# 4        -47.179   8.00      1.04
# ...          ...    ...       ...
# 53242    -63.940   9.10      1.05
# 53243    -66.571  10.00      1.05
# 53244    -68.681  12.00      1.06
# 53245    -65.304  81.55      1.42
# 53246    -61.260  20.70      1.11
#
# [53247 rows x 11 columns]

# %%
df_agrupado.describe()
# Out:
#         diasemchuva  precipitacao     riscofogo      latitude     longitude  \
# count  53247.000000  53247.000000  53247.000000  53247.000000  53247.000000
# mean      22.126617      0.805653      0.674462    -12.225387    -50.045962
# std       30.810885      3.131065      0.378404      7.668856      7.082311
# min        0.000000      0.000000      0.000000    -33.388000    -73.560000
# 25%        3.000000      0.000000      0.300000    -17.468000    -54.435000
# 50%        8.000000      0.000000      0.900000    -10.934000    -49.249000
# 75%       26.500000      0.100000      1.000000     -6.406000    -44.890000
# max      120.000000     95.350000      1.000000      5.122000    -34.823000
#
#                 frp      frp_norm
# count  53247.000000  53247.000000
# mean      36.630517      1.187810
# std       47.965085      0.245923
# min        0.000000      1.000000
# 25%       13.400000      1.070000
# 50%       22.800000      1.120000
# 75%       41.700000      1.210000
# max     1755.500000     10.000000

# %%
#relatorio_completo = ProfileReport(df_agrupado, title='Relatorio Completo')
#relatorio_completo.to_file('relatorio_completo.html')

# %%
df_agrupado.to_csv('clean_df.csv')

# %%
df_agrupado_frp_ate_500 = df_agrupado[df_agrupado['frp'] <= 500]

# %%
df_agrupado_frp_ate_500
# Out:
#                  datahora              estado                 municipio  \
# 0     2020-01-01 16:45:00  MATO GROSSO DO SUL                   AMAMBAI
# 1     2020-01-01 16:45:00  MATO GROSSO DO SUL      APARECIDA DO TABOADO
# 2     2020-01-01 16:45:00  MATO GROSSO DO SUL  RIO VERDE DE MATO GROSSO
# 3     2020-01-01 16:45:00  MATO GROSSO DO SUL               TRES LAGOAS
# 4     2020-01-01 16:45:00        MINAS GERAIS                COROMANDEL
# ...                   ...                 ...                       ...
# 53242 2020-12-31 18:00:00            AMAZONAS                  CANUTAMA
# 53243 2020-12-31 18:00:00            AMAZONAS                    LABREA
# 53244 2020-12-31 18:00:00            AMAZONAS  SAO GABRIEL DA CACHOEIRA
# 53245 2020-12-31 18:00:00            RONDONIA               NOVA MAMORE
# 53246 2020-12-31 18:00:00             RORAIMA               ALTO ALEGRE
#
#                 bioma  diasemchuva  precipitacao  riscofogo  latitude  \
# 0      Mata Atlantica          0.0          2.35       0.10   -23.176
# 1             Cerrado          5.0          0.20       0.20   -20.180
# 2             Cerrado          3.0          0.30       0.80   -18.932
# 3             Cerrado          3.0          0.10       0.60   -20.476
# 4             Cerrado          0.0          0.10       0.80   -18.137
# ...               ...          ...           ...        ...       ...
# 53242        Amazonia          0.0          0.50       0.00    -7.998
# 53243        Amazonia          1.5          1.85       0.00    -8.767
# 53244        Amazonia          0.0          2.20       0.00     0.285
# 53245        Amazonia          0.0          1.15       0.25   -10.475
# 53246        Amazonia          0.0          0.40       0.10     2.937
#
#        longitude    frp  frp_norm
# 0        -54.727  45.25      1.23
# 1        -51.543  12.60      1.06
# 2        -54.506  30.20      1.15
# 3        -52.129  27.10      1.14
# 4        -47.179   8.00      1.04
# ...          ...    ...       ...
# 53242    -63.940   9.10      1.05
# 53243    -66.571  10.00      1.05
# 53244    -68.681  12.00      1.06
# 53245    -65.304  81.55      1.42
# 53246    -61.260  20.70      1.11
#
# [53185 rows x 11 columns]
