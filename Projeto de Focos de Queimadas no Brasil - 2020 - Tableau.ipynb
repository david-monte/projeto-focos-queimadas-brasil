# %%
import pandas as pd
import numpy as np
import plotly.express as px
from pandas_profiling import ProfileReport

# %%
df = pd.read_csv('clean_df_tableau.csv', sep=';', decimal=',')
df
# Out:
#                 Bioma Classificação - Risco de Fogo  \
# 0      Mata Atlantica                        Mínimo
# 1             Cerrado                         Baixo
# 2             Cerrado                          Alto
# 3             Cerrado                         Médio
# 4             Cerrado                          Alto
# ...               ...                           ...
# 53242        Amazonia                        Mínimo
# 53243        Amazonia                        Mínimo
# 53244        Amazonia                        Mínimo
# 53245        Amazonia                         Baixo
# 53246        Amazonia                        Mínimo
#
#       Classificação - Risco de Fogo (cópia)        Data             Datahora  \
# 0                                    Mínimo  01/01/2020  01/01/2020 16:45:00
# 1                                     Baixo  01/01/2020  01/01/2020 16:45:00
# 2                                      Alto  01/01/2020  01/01/2020 16:45:00
# ...

# %%
df_agrupado_frp_ate_500 = df[df['Frp'] <= 500]

# %%
df_agrupado_frp_ate_500
# Out:
#                 Bioma Classificação - Risco de Fogo  \
# 0      Mata Atlantica                        Mínimo
# 1             Cerrado                         Baixo
# 2             Cerrado                          Alto
# 3             Cerrado                         Médio
# 4             Cerrado                          Alto
# ...               ...                           ...
# 53242        Amazonia                        Mínimo
# 53243        Amazonia                        Mínimo
# 53244        Amazonia                        Mínimo
# 53245        Amazonia                         Baixo
# 53246        Amazonia                        Mínimo
#
#       Classificação - Risco de Fogo (cópia)        Data             Datahora  \
# 0                                    Mínimo  01/01/2020  01/01/2020 16:45:00
# 1                                     Baixo  01/01/2020  01/01/2020 16:45:00
# 2                                      Alto  01/01/2020  01/01/2020 16:45:00
# ...

# %%
df_agrupado_frp_ate_500.describe()
# Out:
#        Dias Sem Chuva           Frp      Latitude     Longitude  Precipitacao  \
# count    53185.000000  53185.000000  53185.000000  53185.000000  53185.000000
# mean        22.114092     35.837670    -12.224820    -50.045192      0.806391
# std         30.807000     41.270141      7.671644      7.083727      3.132712
# min          0.000000      0.000000    -33.388000    -73.560000      0.000000
# 25%          3.000000     13.400000    -17.471000    -54.434000      0.000000
# 50%          8.000000     22.800000    -10.931000    -49.248000      0.000000
# 75%         26.000000     41.500000     -6.403000    -44.890000      0.100000
# max        120.000000    498.800000      5.122000    -34.823000     95.350000
#
#        Risco de Fogo            F1      frp_norm
# count   53185.000000  53185.000000  53185.000000
# mean        0.674181  26619.014384      1.183746
# std         0.378475  15375.625695      0.211602
# min         0.000000      0.000000      1.000000
# ...

# %%
df_agrupado_frp_ate_500.to_csv('clean_df_tableau_500.csv')
